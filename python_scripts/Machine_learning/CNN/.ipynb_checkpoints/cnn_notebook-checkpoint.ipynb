# %% [markdown]
# # CNN script

# %%
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
import os,glob
import numpy as np

# %% [raw]
# reading the images and reshaping them to standard size

# %%
file = "test_set/cats/cat.4001.jpg"
img = plt.imread(file)
mat = cv2.resize(img,(300,300))

# %%
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(mat)

# %%
12*12
# Out:
# 144
